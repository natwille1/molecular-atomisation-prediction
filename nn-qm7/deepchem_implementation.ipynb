# %%
import numpy as np
import tensorflow as tf
import deepchem as dc
from sklearn.kernel_ridge import KernelRidge

# %%
dataset_file = "../../deepchem/datasets/gdb1k.sdf"
smiles_field = "smiles"
mol_field = "mol"
featurizer = dc.feat.CoulombMatrixEig(23, remove_hydrogens=False)

loader = dc.data.SDFLoader(
      tasks=["atomization_energy"], smiles_field="smiles",
      featurizer=featurizer,
      mol_field="mol")
dataset = loader.featurize(dataset_file)
# Out:
# Loading raw samples now.
# shard_size: 8192
# Reading structures from ../../deepchem/datasets/gdb1k.sdf.
# Currently featurizing feature_type: CoulombMatrixEig
# Featurizing sample 0
# TIMING: featurizing shard 0 took 0.627 s
# TIMING: dataset construction took 0.851 s
# Loading dataset from disk.

# %%
# Split dataset
random_splitter = dc.splits.RandomSplitter()
train_dataset, valid_dataset, test_dataset = random_splitter.train_valid_test_split(dataset)

# Apply normalisation transformer
transformers = [
    dc.trans.NormalizationTransformer(transform_X=True, dataset=train_dataset),
    dc.trans.NormalizationTransformer(transform_y=True, dataset=train_dataset)]

for dataset in [train_dataset, valid_dataset, test_dataset]:
    for transformer in transformers:
        dataset = transformer.transform(dataset)
# Out:
# TIMING: dataset construction took 0.012 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.009 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.009 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.042 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.012 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.008 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.007 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.009 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.009 s
# Loading dataset from disk.

# %%
def krr_model_builder(model_params, model_dir):
    sklearn_model = KernelRidge(**model_params)
    return dc.models.SklearnModel(sklearn_model, model_dir)

params_dict = {
    "kernel": ["laplacian", "linear"],
    "alpha": [0.0001, 0.001, 0.01, 0.01],
    "gamma": [0.0001, 0.001, 0.01, 0.1]
}

metric = dc.metrics.Metric(dc.metrics.mean_absolute_error)

optimizer = dc.hyper.HyperparamOpt(krr_model_builder)
best_krr, best_krr_hyperparams, all_krr_results = optimizer.hyperparam_search(
    params_dict, train_dataset, valid_dataset, transformers,
    metric=metric)
# Out:
# Fitting model 1/32
# hyperparameters: {'kernel': 'laplacian', 'gamma': 0.0001, 'alpha': 0.0001}
# computed_metrics: [86283.96601157558]
# Model 1/32, Metric mean_absolute_error, Validation set 0: 86283.966012
# 	best_validation_score so far: 86283.966012
# Fitting model 2/32
# hyperparameters: {'kernel': 'laplacian', 'gamma': 0.0001, 'alpha': 0.001}
# computed_metrics: [76013.57938648511]
# Model 2/32, Metric mean_absolute_error, Validation set 1: 76013.579386
# 	best_validation_score so far: 86283.966012
# Fitting model 3/32
# hyperparameters: {'kernel': 'laplacian', 'gamma': 0.0001, 'alpha': 0.01}
# computed_metrics: [71806.19872522898]
# Model 3/32, Metric mean_absolute_error, Validation set 2: 71806.198725
# 	best_validation_score so far: 86283.966012
# Fitting model 4/32
# hyperparameters: {'kernel': 'laplacian', 'gamma': 0.0001, 'alpha': 0.01}
# computed_metrics: [71806.19872522898]
# Model 4/32, Metric mean_absolute_error, Validation set 3: 71806.198725
# 	best_validation_score so far: 86283.966012
# Fitting model 5/32
# hyperparameters: {'kernel': 'laplacian', 'gamma': 0.001, 'alpha': 0.0001}
# computed_metrics: [94832.37118527446]
# Model 5/32, Metric mean_absolute_error, Validation set 4: 94832.371185
# 	best_validation_score so far: 94832.371185
# Fitting model 6/32
# hyperparameters: {'kernel': 'laplacian', 'gamma': 0.001, 'alpha': 0.001}
# computed_metrics: [85834.14715866957]
# Model 6/32, Metric mean_absolute_error, Validation set 5: 85834.147159
# 	best_validation_score so far: 94832.371185
# Fitting model 7/32
# hyperparameters: {'kernel': 'laplacian', 'gamma': 0.001, 'alpha': 0.01}
# computed_metrics: [75548.1938478731]
# Model 7/32, Metric mean_absolute_error, Validation set 6: 75548.193848
# 	best_validation_score so far: 94832.371185
# Fitting model 8/32
# hyperparameters: {'kernel': 'laplacian', 'gamma': 0.001, 'alpha': 0.01}
# computed_metrics: [75548.1938478731]
# Model 8/32, Metric mean_absolute_error, Validation set 7: 75548.193848
# 	best_validation_score so far: 94832.371185
# Fitting model 9/32
# hyperparameters: {'kernel': 'laplacian', 'gamma': 0.01, 'alpha': 0.0001}
# computed_metrics: [96936.25835761151]
# Model 9/32, Metric mean_absolute_error, Validation set 8: 96936.258358
# 	best_validation_score so far: 96936.258358
# Fitting model 10/32
# hyperparameters: {'kernel': 'laplacian', 'gamma': 0.01, 'alpha': 0.001}
# computed_metrics: [95558.90373667683]
# Model 10/32, Metric mean_absolute_error, Validation set 9: 95558.903737
# 	best_validation_score so far: 96936.258358
# Fitting model 11/32
# hyperparameters: {'kernel': 'laplacian', 'gamma': 0.01, 'alpha': 0.01}
# computed_metrics: [87022.59447073912]
# Model 11/32, Metric mean_absolute_error, Validation set 10: 87022.594471
# 	best_validation_score so far: 96936.258358
# Fitting model 12/32
# hyperparameters: {'kernel': 'laplacian', 'gamma': 0.01, 'alpha': 0.01}
# computed_metrics: [87022.59447073912]
# Model 12/32, Metric mean_absolute_error, Validation set 11: 87022.594471
# 	best_validation_score so far: 96936.258358
# Fitting model 13/32
# hyperparameters: {'kernel': 'laplacian', 'gamma': 0.1, 'alpha': 0.0001}
# computed_metrics: [87454.58108578868]
# Model 13/32, Metric mean_absolute_error, Validation set 12: 87454.581086
# 	best_validation_score so far: 96936.258358
# Fitting model 14/32
# hyperparameters: {'kernel': 'laplacian', 'gamma': 0.1, 'alpha': 0.001}
# computed_metrics: [87431.26302764245]
# Model 14/32, Metric mean_absolute_error, Validation set 13: 87431.263028
# 	best_validation_score so far: 96936.258358
# Fitting model 15/32
# hyperparameters: {'kernel': 'laplacian', 'gamma': 0.1, 'alpha': 0.01}
# computed_metrics: [87217.39808552203]
# Model 15/32, Metric mean_absolute_error, Validation set 14: 87217.398086
# 	best_validation_score so far: 96936.258358
# Fitting model 16/32
# hyperparameters: {'kernel': 'laplacian', 'gamma': 0.1, 'alpha': 0.01}
# computed_metrics: [87217.39808552203]
# Model 16/32, Metric mean_absolute_error, Validation set 15: 87217.398086
# 	best_validation_score so far: 96936.258358
# Fitting model 17/32
# hyperparameters: {'kernel': 'linear', 'gamma': 0.0001, 'alpha': 0.0001}
# computed_metrics: [76408.94370441262]
# Model 17/32, Metric mean_absolute_error, Validation set 16: 76408.943704
# 	best_validation_score so far: 96936.258358
# Fitting model 18/32
# hyperparameters: {'kernel': 'linear', 'gamma': 0.0001, 'alpha': 0.001}
# computed_metrics: [76391.83349555879]
# Model 18/32, Metric mean_absolute_error, Validation set 17: 76391.833496
# 	best_validation_score so far: 96936.258358
# Fitting model 19/32
# hyperparameters: {'kernel': 'linear', 'gamma': 0.0001, 'alpha': 0.01}
# computed_metrics: [76251.16622770258]
# Model 19/32, Metric mean_absolute_error, Validation set 18: 76251.166228
# 	best_validation_score so far: 96936.258358
# Fitting model 20/32
# hyperparameters: {'kernel': 'linear', 'gamma': 0.0001, 'alpha': 0.01}
# computed_metrics: [76251.16622770258]
# Model 20/32, Metric mean_absolute_error, Validation set 19: 76251.166228
# 	best_validation_score so far: 96936.258358
# Fitting model 21/32
# hyperparameters: {'kernel': 'linear', 'gamma': 0.001, 'alpha': 0.0001}
# computed_metrics: [76408.94370441262]
# Model 21/32, Metric mean_absolute_error, Validation set 20: 76408.943704
# 	best_validation_score so far: 96936.258358
# Fitting model 22/32
# hyperparameters: {'kernel': 'linear', 'gamma': 0.001, 'alpha': 0.001}
# computed_metrics: [76391.83349555879]
# Model 22/32, Metric mean_absolute_error, Validation set 21: 76391.833496
# 	best_validation_score so far: 96936.258358
# Fitting model 23/32
# hyperparameters: {'kernel': 'linear', 'gamma': 0.001, 'alpha': 0.01}
# computed_metrics: [76251.16622770258]
# Model 23/32, Metric mean_absolute_error, Validation set 22: 76251.166228
# 	best_validation_score so far: 96936.258358
# Fitting model 24/32
# hyperparameters: {'kernel': 'linear', 'gamma': 0.001, 'alpha': 0.01}
# computed_metrics: [76251.16622770258]
# Model 24/32, Metric mean_absolute_error, Validation set 23: 76251.166228
# 	best_validation_score so far: 96936.258358
# Fitting model 25/32
# hyperparameters: {'kernel': 'linear', 'gamma': 0.01, 'alpha': 0.0001}
# computed_metrics: [76408.94370441262]
# Model 25/32, Metric mean_absolute_error, Validation set 24: 76408.943704
# 	best_validation_score so far: 96936.258358
# Fitting model 26/32
# hyperparameters: {'kernel': 'linear', 'gamma': 0.01, 'alpha': 0.001}
# computed_metrics: [76391.83349555879]
# Model 26/32, Metric mean_absolute_error, Validation set 25: 76391.833496
# 	best_validation_score so far: 96936.258358
# Fitting model 27/32
# hyperparameters: {'kernel': 'linear', 'gamma': 0.01, 'alpha': 0.01}
# computed_metrics: [76251.16622770258]
# Model 27/32, Metric mean_absolute_error, Validation set 26: 76251.166228
# 	best_validation_score so far: 96936.258358
# Fitting model 28/32
# hyperparameters: {'kernel': 'linear', 'gamma': 0.01, 'alpha': 0.01}
# computed_metrics: [76251.16622770258]
# Model 28/32, Metric mean_absolute_error, Validation set 27: 76251.166228
# 	best_validation_score so far: 96936.258358
# Fitting model 29/32
# hyperparameters: {'kernel': 'linear', 'gamma': 0.1, 'alpha': 0.0001}
# computed_metrics: [76408.94370441262]
# Model 29/32, Metric mean_absolute_error, Validation set 28: 76408.943704
# 	best_validation_score so far: 96936.258358
# Fitting model 30/32
# hyperparameters: {'kernel': 'linear', 'gamma': 0.1, 'alpha': 0.001}
# computed_metrics: [76391.83349555879]
# Model 30/32, Metric mean_absolute_error, Validation set 29: 76391.833496
# 	best_validation_score so far: 96936.258358
# Fitting model 31/32
# hyperparameters: {'kernel': 'linear', 'gamma': 0.1, 'alpha': 0.01}
# computed_metrics: [76251.16622770258]
# Model 31/32, Metric mean_absolute_error, Validation set 30: 76251.166228
# 	best_validation_score so far: 96936.258358
# Fitting model 32/32
# hyperparameters: {'kernel': 'linear', 'gamma': 0.1, 'alpha': 0.01}
# computed_metrics: [76251.16622770258]
# Model 32/32, Metric mean_absolute_error, Validation set 31: 76251.166228
# 	best_validation_score so far: 96936.258358
# computed_metrics: [351.8588052905078]
# Best hyperparameters: ('laplacian', 0.01, 0.0001)
# train_score: 351.858805
# validation_score: 96936.258358

# %%
# Metrics to models
metric = [
    dc.metrics.Metric(dc.metrics.mean_absolute_error)
    dc.metrics.Metric(dc.metrics.pearson_r2_score, mode="regression")
]
